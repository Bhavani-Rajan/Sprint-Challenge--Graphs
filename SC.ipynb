# %%
from room import Room
from player import Player
from world import World
from util import *
import random
from ast import literal_eval

# %%
# Load world
world = World()

# You may uncomment the smaller graphs for development and testing purposes.
# map_file = "maps/test_line.txt"
# map_file = "maps/test_cross.txt"
# map_file = "maps/test_loop.txt"
# map_file = "maps/test_loop_fork.txt"
map_file = "maps/main_maze.txt"

# Loads the map into a dictionary
room_graph=literal_eval(open(map_file, "r").read())
world.load_graph(room_graph)

# Print an ASCII map
world.print_rooms()
# Out:
# #####
# #                                                                                                                                                           #
# #                                                        434       497--366--361  334--384--435  476                                                        #
# #                                                         |                   |    |              |                                                         #
# #                                                         |                   |    |              |                                                         #
# #                                              477--443  425            386--354--321  338  313  380--445--446                                              #
# #                                                    |    |              |         |    |    |    |    |                                                    #
# ...

# %%
class RoomGraph:
    def __init__(self):
        self.vertices = {}  # This is our adjacency list
        self.order_rooms = []
    def generate_room_graph(self,player):
        starting_room = player.current_room
        visited = set()
        # Create a Stack and push starting vertex
        ss = Stack()
        ss.push([starting_room])
        # While Queue is not empty:
        while ss.size() > 0:
        # pop the last added vertex
            path = ss.pop()
            room = path[-1]
            if room not in visited:
                # DO THE THING!!!!!!!
                self.order_rooms.append(room.id)
                self.vertices[room.id] ={}
                for exit in room.get_exits():
                    self.vertices[room.id][room.get_room_in_direction(exit).id]= exit
                # mark as visited
                visited.add(room)
#                     # push all neightbors
#                 for i in range(4):
#                     temp = random.choice(exit)
#                     print(temp)
#                     exit.remove(temp)
                exits = room.get_exits()
                for i in range(len(exits)):
                    direction = random.choice(exits)
                    exits.remove(direction)
                    new_path = list(path)
                    new_path.append(room.get_room_in_direction(direction))
                    ss.push(new_path)
        return self.vertices,self.order_rooms

    def search(self, starting_vertex, destination_vertex):
            """
            Return a list containing the shortest path from
            starting_vertex to destination_vertex in
            breath-first order.
            """
            graph = self.vertices
            # Create a q and enqueue starting vertex
            qq = Queue()
            qq.enqueue([starting_vertex])
            # Create a set of traversed vertices
            visited = set()
            # While queue is not empty:
            while qq.size() > 0:
                # dequeue/pop the first vertex
                path = qq.dequeue()
                # if not visited
                if(path[-1] == destination_vertex):
                    return path
                if path[-1] not in visited:
                    # DO THE THING!!!!!!!
                    # mark as visited
                    visited.add(path[-1])
                    # enqueue all neightbors
                    for next_vert in graph[path[-1]].keys():
                        new_path = list(path)
                        new_path.append(next_vert)
                        qq.enqueue(new_path)

# %%
def traverse_room():  
    graph_r = RoomGraph()
    player = Player(world.starting_room)
    graph,order = graph_r.generate_room_graph(player)
    # order = get_path(graph)
    # print(order)
    traversal_path =[]
    i = 0
    while(i < (len(order) - 1)):
        if(order[i+1] in graph[order[i]].keys()):
            traversal_path.append(graph[order[i]][order[i+1]])
        else:
            path = graph_r.search(order[i],order[i+1])
            j=0
            while(j < (len(path)-1)):
                if(path[j+1] in graph[path[j]].keys()):
                    traversal_path.append(graph[path[j]][path[j+1]])
                else:
                    traversal_path.append('?')
                j += 1
        i += 1
    # Fill this out with directions to walk
    # traversal_path = ['n', 'n']
 'w', 's', 'w', 'e', 'n', 'w', 'e', 'e', 'e', 'n', 'n', 'n', 's', 's', 'w', 'e', 's', 'e', 'n', 'n', 's', 's', 'e', 's', 'e', 'n', 'n', 'n', 'n', 's', 's', 's', 's', 's', 'e', 'n', 's', 'e', 'e', 'e', 'n', 'w', 'n', 's', 'e', 'n', 'n', 'w', 'n', 's', 'w', 'n', 'w', 'e', 's', 'e', 'e', 's', 's', 's', 'e', 'n', 's', 'e', 's', 'n', 'n', 'n', 'n', 'e', 'e', 'w', 'w', 'n', 'e', 'e', 'n', 's', 'e', 'e', 'w', 'n', 'e', 'n', 'e', 'n', 's', 'e', 'n', 's', 'e', 'w', 'w', 'w', 's', 'e', 'w', 'w', 'n', 'n', 'n', 'n', 's', 's', 'e', 'n', 'e', 'n', 'n', 's', 'e', 's', 'n', 'e', 'w', 'w', 's', 'w', 'n', 's', 's', 'w', 's', 'w', 'n', 'n', 'n', 'n', 'e', 'e', 'w', 'w', 's', 'w', 'n', 'w', 'w', 'e', 'e', 's', 'w', 's', 's', 's', 'e', 'n', 'n', 's', 's', 'w', 'w', 'w', 'w', 'w', 's', 'w', 'e', 'n', 'w', 'w', 'n', 's', 'e', 'n', 's', 'e', 'e', 'n', 'w', 'n', 'n', 'w', 'e', 's', 's', 'e', 'n', 'n', 'n', 's', 's', 's', 's', 'e', 'e', 'n', 'w', 'n', 's', 'e', 'n', 's', 's', 'e', 's', 'e', 'w', 's', 's', 's', 'w', 'n', 'n', 'w', 'n', 'e', 'w', 'w', 'e', 's', 'e', 's', 's', 'e', 's', 's', 'w', 's', 's', 'w', 'w', 'n', 's', 'w', 'n', 's', 'w', 'w', 'n', 'w', 'n', 'w', 'e', 's', 'w', 'e', 'e', 's', 's', 's', 'n', 'w', 'w', 'w', 'e', 'e', 's', 'w', 'w', 'w', 's', 'w', 'w', 'e', 's', 'e', 's', 's', 'w', 'n', 'w', 'e', 's', 'e', 'e', 's', 'w', 'w', 's', 'w', 's', 'n', 'e', 'n', 'e', 'e', 'e', 'n', 's', 'e', 'e', 's', 'w', 's', 'w', 's', 'n', 'e', 'n', 'w', 'w', 's', 'w', 'w', 'e', 'e', 's', 'w', 's', 'w', 'e', 's', 'w', 'e', 's', 'w', 'w', 'e', 'e', 's', 'n', 'n', 'n', 'n', 'w', 'w', 'w', 'e', 'e', 'e', 'e', 's', 's', 's', 'e', 'w', 's', 'e', 'w', 'n', 'n', 'n', 'n', 'n', 'n', 'w']
    
    # TRAVERSAL TEST



    visited_rooms = set()
    player.current_room = world.starting_room
    visited_rooms.add(player.current_room)

    # print(traversal_path)
    for move in traversal_path:
        player.travel(move)
        visited_rooms.add(player.current_room)
        
#     if (len(traversal_path)<960):
#         path = traversal_path
#         print("yes")
#         return path
#     return


    if len(visited_rooms) == len(room_graph):
        print(f"TESTS PASSED: {len(traversal_path)} moves, {len(visited_rooms)} rooms visited")
    else:
        print("TESTS FAILED: INCOMPLETE TRAVERSAL")
        print(f"{len(room_graph) - len(visited_rooms)} unvisited rooms")

# %%
traverse_room()
# Out:
# TESTS PASSED: 959 moves, 500 rooms visited

# %%
path =[]
for i in range(10000):
    path.append(traverse_room())
# Out:
# yes

# %%
store_960 = path

# %%
l = path
for i in range(l.count(None)):
    l.remove(None)

# %%
len(l[0])
# Out:
# 959

# %%
print(l[0])
# Out:
# ['n', 's', 's', 'w', 'e', 'n', 'w', 'w', 's', 'w', 's', 's', 'n', 'n', 'e', 'n', 'e', 'n', 'w', 'w', 's', 'n', 'w', 's', 's', 's', 'w', 'n', 'w', 'w', 'w', 'e', 'e', 'e', 's', 
# Out:
# (2, 968, 962)

# %%
print(l[1])
# Out:
# ['s', 'w', 'e', 'n', 'n', 's', 'w', 'w', 's', 'w', 's', 's', 'n', 'n', 'e', 'n', 'e', 'n', 'w', 'w', 's', 'n', 'w', 's', 's', 's', 's', 'w', 's', 'w', 'e', 'n', 'w', 'e', 'e', 's', 's', 's', 's', 'w', 's', 's', 's', 'n', 'n', 'w', 's', 's', 'w', 'e', 'n', 'w', 'e', 'n', 'e', 'n', 'e', 's', 's', 's', 's', 'w', 'e', 'n', 'e', 's', 'n', 'e', 's', 's', 's', 'w', 'e', 'n', 'e', 'w', 'n', 'n', 'w', 'w', 'n', 'n', 'n', 'n', 'n', 'w', 's', 'w', 's', 'w', 's', 'n', 'e', 'n', 'w', 'w', 's', 's', 's', 's', 's', 'e', 'w', 's', 'e', 'w', 'n', 'n', 'n', 'n', 'w', 'w', 'w', 'w', 'e', 'e', 'e', 's', 's', 'w', 'e', 's', 'w', 'w', 'e', 'e', 's', 'n', 'n', 'n', 'w', 'e', 'n', 'e', 'n', 'w', 'w', 'e', 'e', 'n', 'w', 'e', 'e', 'e', 'e', 'n', 'w', 'w', 'n', 's', 'w', 'w', 'w', 's', 'w', 's', 'n', 'e', 'n', 'e', 'e', 'n', 'w', 'w', 'n', 'w', 'e', 's', 'e', 'n', 'n', 'w', 'n', 'w', 'e', 'e', 'n', 'n', 's', 'w', 'w', 'e', 'n', 's', 'e', 'e', 'e', 'e', 'n', 'w', 'w', 'e', 'e', 'e', 's', 'n', 'n', 'n', 'w', 'n
# ...

# %%
stored_path_970 = path 
stored_path_970
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
exit = ['n','s','e','w']
for i in range(4):
    temp = random.choice(exit)
    print(temp)
    exit.remove(temp)
# Out:
# e
# w
# s
# n

# %%
#     player.current_room.id
#     player.current_room.get_exits()
#     player.travel(direction)

def generate_room_graph():
    starting_room = world.starting_room
    visited = set()
    room_graph ={}
    order =[]
    # Create a Stack and push starting vertex
    ss = Stack()
    ss.push([player.current_room])
    # While Queue is not empty:
    while ss.size() > 0:
    # pop the last added vertex
        path = ss.pop()
        room = path[-1]
        if room not in visited:
            # DO THE THING!!!!!!!
            order.append(room.id)
            room_graph[room.id] ={}
            for exit in room.get_exits():
                room_graph[room.id][room.get_room_in_direction(exit).id]= exit
            # mark as visited
            visited.add(room)
                # push all neightbors
            for direction in room.get_exits():
                new_path = list(path)
                new_path.append(room.get_room_in_direction(direction))
                ss.push(new_path)
    return room_graph,order

# %%
def search(graph, starting_vertex, destination_vertex):
        """
        Return a list containing the shortest path from
        starting_vertex to destination_vertex in
        breath-first order.
        """
        graph = graph
        # Create a q and enqueue starting vertex
        qq = Queue()
        qq.enqueue([starting_vertex])
        # Create a set of traversed vertices
        visited = set()
        # While queue is not empty:
        while qq.size() > 0:
            # dequeue/pop the first vertex
            path = qq.dequeue()
            # if not visited
            if(path[-1] == destination_vertex):
                return path
            if path[-1] not in visited:
                # DO THE THING!!!!!!!
#                 print(path[-1])
                # mark as visited
                visited.add(path[-1])
                # enqueue all neightbors
                for next_vert in graph[path[-1]].keys():
                    new_path = list(path)
                    new_path.append(next_vert)
                    qq.enqueue(new_path)

# %%
#     player.current_room.id
#     player.current_room.get_exits()
#     player.travel(direction)
player = Player(world.starting_room)
graph,order = generate_room_graph()
# order = get_path(graph)
# print(order)
traversal_path =[]
i = 0
while(i < (len(order) - 1)):
    if(order[i+1] in graph[order[i]].keys()):
        traversal_path.append(graph[order[i]][order[i+1]])
    else:
        path = search(graph,order[i],order[i+1])
        j=0
        while(j < (len(path)-1)):
            if(path[j+1] in graph[path[j]].keys()):
                traversal_path.append(graph[path[j]][path[j+1]])
            else:
                traversal_path.append('?')
            j += 1
    i += 1

# %%
# Fill this out with directions to walk
# traversal_path = ['n', 'n']
# traversal_path = ['n','n','s','s','s','s','n','n']
# traversal_path = ['e', 'e', 'w', 'w', 'w', 'w', 's', 's', 'e', 'e', 'n', 'n', 'n', 'e', 'e', 'n', 's', 'w', 'w', 'w', 'w', 'n', 's', 'e', 'e', 'n']
# traversal_path=generate_path(player)


# TRAVERSAL TEST



visited_rooms = set()
player.current_room = world.starting_room
visited_rooms.add(player.current_room)

# print(traversal_path)
for move in traversal_path:
    player.travel(move)
    visited_rooms.add(player.current_room)

if len(visited_rooms) == len(room_graph):
    print(f"TESTS PASSED: {len(traversal_path)} moves, {len(visited_rooms)} rooms visited")
else:
    print("TESTS FAILED: INCOMPLETE TRAVERSAL")
    print(f"{len(room_graph) - len(visited_rooms)} unvisited rooms")
# Out:
# TESTS PASSED: 997 moves, 500 rooms visited

# %%
def get_path(room_graph):
    starting_room = 0
    visited = set()
    room_graph = room_graph
    order=[]
    
    # Create a Stack and push starting vertex
    ss = Stack()
    ss.push([starting_room])

    # While Stack is not empty:
    while ss.size() > 0:
    # pop the last added vertex
        path = ss.pop()
        room = path[-1]
        # if not visited
        if room not in visited:
            # DO THE THING!!!!!!!           
            order.append(room)
            # mark as visited
            visited.add(room)
                # push all neightbors
            for next_room in room_graph[room].keys():
                new_path = list(path)
                new_path.append(next_room)
                ss.push(new_path)        
    return order

# %%
print(traversal_path)
# Out:
# ['e', 'e', 'w', 'w', 'w', 'w', 's', 's', 'e', 'e', 'n', 'n', 'n', 'e', 'e', 'n', 's', 'w', 'w', 'w', 'w', 'n', 's', 'e', 'e', 'n']

# %%
# Out:
# TESTS PASSED: 997 moves, 500 rooms visited

# %%
path_node=bfs(graph,4,7)

# %%
path_node
# Out:
# [4, 3, 0, 7]

# %%
i = 0
while(i < (len(path_node) - 1)):
# for node in path_node:
    print(graph[path_node[i]])
    print(path_node[i],path_node[i+1])
    
    print(graph[path_node[i]][path_node[i + 1]])
    i += 1
# Out:
# {3: 'w'}
# 4 3
# w
# {0: 'w', 4: 'e'}
# 3 0
# w
# {1: 'n', 5: 's', 7: 'w', 3: 'e'}
# 0 7
# w

# %%
path = get_path(graph)
print(path)
# len_path =[]
# max_len_path =[]
# for l in path:
#     max_len=max(path)
#     len_path.append(len(l))
# print(len_path)
# max_path = 
# for i in range(4):
    
#     maxList = max(path, key = len) 
#     print(maxList)
#     path.remove(maxList)

# print(path)
# maxList = max(path, key = len) 
# print(maxList)
# maxList = max(new_path, key = len) 
# print(maxList)
# Out:
# [[0], [0, 3], [0, 3, 4], [0, 7], [0, 7, 8], [0, 7, 8, 9], [0, 7, 8, 9, 10], [0, 7, 8, 9, 10, 11], [0, 7, 8, 9, 10, 11, 6], [0, 7, 8, 9, 10, 11, 6, 5], [0, 1], [0, 1, 12], [0, 1, 12, 13], [0, 1, 12, 13, 14], [0, 1, 15], [0, 1, 15, 16], [0, 1, 15, 16, 17], [0, 1, 2]]
# [0, 7, 8, 9, 10, 11, 6, 5]
# [0, 7, 8, 9, 10, 11, 6]
# [0, 7, 8, 9, 10, 11]
# [0, 7, 8, 9, 10]

# %%
l = []
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
def get_path(graph):
    t_path = []
    
    graph = graph
    starting_room = 0
    curr = starting_room
    visited=set()
    ss = Stack()
    ss.push([starting_room])
    
    while(ss.size() > 0):
        path = ss.pop()
        if path[-1] not in visited:
            ## do it here
            print(path[-1])
            visited.add(path[-1])
            
            for direction in graph[curr].keys():
                new_path = list(path)
                new_path.append(graph[curr][direction])
                t_path.append(direction)
#                 print(direction)
                ss.push(new_path)
                
    return t_path

# %%
path = get_path(graph)
print(path)
# Out:
# 0
# 3
# 7
# 5
# 1
# ['n', 's', 'w', 'e', 'n', 's', 'w', 'e', 'n', 's', 'w', 'e', 'n', 's', 'w', 'e', 'n', 's', 'w', 'e']

# %%
player = Player(world.starting_room)
traversal_path=generate_path(player)
# Out:
# -------------------
#
# Room 0
#
#    (3,5)
#
# Exits: [n, s, w, e]
#
# room  0
# n
# s
# w
# e
# room  7
# w
# e
# room  1
# n
# s

# %%
player = Player(world.starting_room)
print(player.current_room.id)
player.travel('n')
print(player.current_room.id)
player.travel('n')
print(player.current_room.get_exits())
player.travel('n')
print(room)
# Out:
# 0
# 1
# ['s']
# You cannot move in that direction.
# None

# %%
# Out:
# TESTS PASSED: 26 moves, 18 rooms visited

# %%
def generate_room_graph():
    starting_room = world.starting_room
    visited = set()
    room_graph ={}
    # Create a Queue and push starting vertex
    qq = Queue()
    qq.enqueue([player.current_room])

#     # Create a Stack and push starting vertex
#     ss = Stack()
#     ss.push([starting_room])

    # While Queue is not empty:
    while qq.size() > 0:
    # pop the last added vertex
        path = qq.dequeue()
        room = path[-1]
#         for room_path in path:
#                 print("path  ",room_path.id)
#         print("-------")
        if room not in visited:
            # DO THE THING!!!!!!!
            for room_path in path:
                print("path  ",room_path.id)
            print("-------")
            room_graph[room.id] ={}
            for exit in room.get_exits():
#                 room_graph[room.id][exit]=room.get_room_in_direction(exit).id
                room_graph[room.id][room.get_room_in_direction(exit).id]= exit
            # mark as visited
            visited.add(room)
                # push all neightbors
            for direction in room.get_exits():
                new_path = list(path)
                new_path.append(room.get_room_in_direction(direction))
                traversal_path.append(direction)
#                 print(direction)
                qq.enqueue(new_path)
#                 print(room.id ,"----",direction)
#     print(traversal_path)            
    return room_graph

# %%
room_graph = generate_room_graph()
# Out:
# path   0
# -------
# path   0
# path   1
# -------
# path   0
# path   5
# -------
# path   0
# path   7
# -------
# path   0
# path   3
# -------
# path   0
# path   1
# path   2
# -------
# path   0
# path   5
# path   6
# -------
# path   0
# path   7
# path   8
# -------
# path   0
# path   3
# path   4
# -------

# %%
room_graph[0][1]
# Out:
# 'n'

# %%
def get_path(room_graph):
    starting_room = 0
    visited = set()
    room_graph = room_graph
    traversal_path=[]
    
    # Create a Stack and push starting vertex
    ss = Stack()
    ss.push([starting_room])

    # While Stack is not empty:
    while ss.size() > 0:
    # pop the last added vertex
        path = ss.pop()
        room = path[-1]
#         print(room)
        # if not visited
        if room not in visited:
            # DO THE THING!!!!!!!
            for room_path in path:
                print("path  ",room_path)
            print("-------")
            # mark as visited
            visited.add(room)
                # push all neightbors
            for next_room in room_graph[room].keys():
                new_path = list(path)
                new_path.append(next_room)
                traversal_path.append(room_graph[room][next_room])
                ss.push(new_path)
#                 print(room.id ,"----",direction)
#     print(traversal_path)            
    return traversal_path

# %%
path =get_path(room_graph)
# Out:
# path   0
# -------
# path   0
# path   3
# -------
# path   0
# path   3
# path   4
# -------
# path   0
# path   7
# -------
# path   0
# path   7
# path   8
# -------
# path   0
# path   5
# -------
# path   0
# path   5
# path   6
# -------
# path   0
# path   1
# -------
# path   0
# path   1
# path   2
# -------

# %%
print(path)
# Out:
# ['n', 's', 'w', 'e', 'w', 'e', 'w', 'w', 'e', 'e', 'n', 's', 'n', 'n', 's', 's']

# %%
# order_rooms = get_path_rooms()
visited_rooms = set()
player.current_room = world.starting_room
visited_rooms.add(player.current_room)
# Out:
# room ---  0
# n
# s
# w
# e
# room ---  1
# n
# s
# room ---  5
# n
# s
# room ---  7
# w
# e
# room ---  3
# w
# e
# room ---  2
# s
# room ---  6
# n
# room ---  8
# e
# room ---  4
# w

# %%
player = Player(world.starting_room)

# Fill this out with directions to walk
# traversal_path = ['n', 'n','s', 's','e','e','w','w','s','s','n','n','w','w']

# traversal_path = get_path(player)
# print((traversal_path))
traversal_path = ['n','s','w','e','n','s','n','s','w','e','w','e','s','n','e','w']

# TRAVERSAL TEST
visited_rooms = set()
player.current_room = world.starting_room
visited_rooms.add(player.current_room)


for move in traversal_path:
    player.travel(move)
    visited_rooms.add(player.current_room)

if len(visited_rooms) == len(room_graph):
    print(f"TESTS PASSED: {len(traversal_path)} moves, {len(visited_rooms)} rooms visited")
else:
    print("TESTS FAILED: INCOMPLETE TRAVERSAL")
    print(f"{len(room_graph) - len(visited_rooms)} unvisited rooms")
# Out:
# TESTS FAILED: INCOMPLETE TRAVERSAL
# 4 unvisited rooms

# %%
# You may find the commands 
# player.current_room.id, 
# player.current_room.get_exits() and 
# player.travel(direction) useful.

# %% [markdown]
# To solve this path, you'll want to construct your own traversal graph. You start in room 0, which contains exits ['n', 's', 'w', 'e'].
#
# Your starting graph should look something like this:
# {
#   0: {'n': '?', 's': '?', 'w': '?', 'e': '?'}
# }
#
# Try moving south and you will find yourself in room 5 which contains exits ['n', 's', 'e']. You can now fill in some entries in your graph:
# {
#   0: {'n': '?', 's': 5, 'w': '?', 'e': '?'},
#   5: {'n': 0, 's': '?', 'e': '?'}
# }

# %%
# generate a graph using bft
def generate_graph():
    room = world.starting_room
    traversal_path=[]
    # Create a Queue and push starting vertex
    qq = Queue()
    qq.enqueue([room])
    # Create a set of traversed vertices
    visited = set()
    room_graph = {}
    # While Queue is not empty:
    while qq.size() > 0:
        # pop the last added vertex
        path = qq.dequeue()
        # if not visited
        room = path[-1]
        if room not in visited:
            # DO THE THING!!!!!!!
            # print(path[-1].id)
            # mark as visited
            
            visited.add(room)
#             print(room.id)
#             room_graph[room.id] ={}
            
#             for exit in room.get_exits():
#                 room_graph[room.id][exit]=room.get_room_in_direction(exit).id
            
            # push all neightbors
            for direction in room.get_exits():
                new_path = list(path)
                new_path.append(room.get_room_in_direction(direction))
                traversal_path.append(direction)
                qq.enqueue(new_path)
    

#     print(len(traversal_path))
    return traversal_path

# %%
# Fill this out with directions to walk
# traversal_path = ['n', 'n']
# player = Player(world.starting_room)
traversal_path = generate_graph()

# traversal_path = generate_graph(player)
# print((traversal_path))
# then do a dft to get the traversal in n,e,s,w order

# %%
# TRAVERSAL TEST
visited_rooms = set()
player.current_room = world.starting_room
# visited_rooms.add(player.current_room)

for move in traversal_path:
    player.travel(move)
    visited_rooms.add(player.current_room)

if len(visited_rooms) == len(room_graph):
    print(f"TESTS PASSED: {len(traversal_path)} moves, {len(visited_rooms)} rooms visited")
else:
    print("TESTS FAILED: INCOMPLETE TRAVERSAL")
    print(f"{len(room_graph) - len(visited_rooms)} unvisited rooms")
# Out:
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# You cannot move in that direction.
# ...

# %%
# then do a dft to get the traversal in n,e,s,w order
def get_path(traversal_graph,starting_room)
# Create a stack and push starting vertex
        ss = []
        ss.push([starting_room])
        # Create a set of traversed vertices
        visited = set()
        # While stack is not empty:
        while ss.size() > 0:
            # pop the last added vertex
            path = ss.pop()
            # if not visited
            if path[-1] not in visited:
                # DO THE THING!!!!!!!
                print(path[-1])
                # mark as visited
                visited.add(path[-1])
                # push all neightbors
                for next_vert in self.get_neighbors(path[-1]):
                    new_path = list(path)
                    new_path.append(next_vert)
                    ss.push(new_path)

# %%
# Out:
# 4
# ['n', 'n', 's', 's']

# %%
d={'n':1,'s':'?'}
print(d.keys())
print(d.values())
# Out:
# dict_keys(['n', 's'])
# dict_values([1, '?'])

# %%
# Out:
# TESTS PASSED: 4 moves, 3 rooms visited

# %%
#######
# UNCOMMENT TO WALK AROUND
#######
player.current_room.print_room_description(player)
while True:
    cmds = input("-> ").lower().split(" ")
    if cmds[0] in ["n", "s", "e", "w"]:
        player.travel(cmds[0], True)
    elif cmds[0] == "q":
        break
    else:
        print("I did not understand that command.")
# Out:
# -------------------
#
# Room 0
#
#    (3,5)
#
# Exits: [n, s, w, e]
# ->  q

# %%
from graph.util import Stack, Queue  # These may come in handy
class AncestorGraph:

    """Represent a graph as a dictionary of vertices mapping labels to edges."""
    def __init__(self):
        self.vertices = {}  # This is our adjacency list

    def add_vertex(self, vertex_id):
        """
        Add a vertex to the graph.
        """
        self.vertices[vertex_id] = set()

    def add_edge(self, v1, v2):
        """
        Add a directed edge to the graph from v1 to v2
        """
        # Check if they exist
        if v1 in self.vertices and v2 in self.vertices:
            # Add the edge
            self.vertices[v1].add(v2)
        else:
            print("ERROR ADDING EDGE: Vertex not found")
    
    def get_parents(self, vertex_id):
        """
        Get all neighbors (edges) of a vertex.
        """
        if vertex_id in self.vertices:
            return self.vertices[vertex_id]
        else:
            return None
        
        

        
    def get_dist_parent(self, starting_vertex):
        
        """
        Gets the distant parent
        
        """
        # Create a stack and push starting vertex
        ss = []
        ss.append([starting_vertex])
        # Create a set of traversed vertices
        visited = set()
        paths = []
        len_path=[]
        dist_parent = -1
        # While stack is not empty:
        while len(ss) > 0:
            # pop the last added vertex
            path = ss.pop(0)
            # if not visited
            if path[-1] not in visited:
                # DO THE THING!!!!!!!
                paths.append(path)
                len_path.append(len(path))
                
                # mark as visited
                visited.add(path[-1])
                # push all neightbors
#                 print(self.get_parents(path[-1]))
                if self.get_parents(path[-1]) is not None:
                    for next_vert in self.get_parents(path[-1]):
                        new_path = list(path)
                        new_path.append(next_vert)
                        ss.append(new_path)
        
        parents=[]
        max_len = max(len_path)
        if max_len == 1:
            dist_parent = -1
        else:
            for path in paths:
                if(len(path) == max_len):
                    parents.append(path[-1])
            dist_parent = min(parents)
#         print(paths)
        return dist_parent

# %%
def earliest_ancestor(ancestors, starting_node):
    ag = AncestorGraph()
    for parent, child in ancestors:
        ag.add_vertex(parent)
        ag.add_vertex(child)
        
    for parent,child in ancestors:
        ag.add_edge(child,parent)
    return ag.get_dist_parent(starting_node)

# %%
import random
import time

class Queue():
    def __init__(self):
        self.queue = []
    def enqueue(self, value):
        self.queue.append(value)
    def dequeue(self):
        if self.size() > 0:
            return self.queue.pop(0)
        else:
            return None
    def size(self):
        return len(self.queue)




class Room:
    get_exits(self)
    get_room_in_direction(self, direction)
class Player:
    travel(self, direction, show_rooms = False)
class MazeGraph:
    def __init__(self):
        self.last_id = 0
        self.users = {}
        self.friendships = {}

    def add_path(self, user_id, friend_id):
        """
        Creates a bi-directional friendship
        """
        

    def add_room(self, name):
        """
        Create a new user with a sequential integer ID
        """
       
        
    def populate_graph_linear(self, num_users, avg_friendships):
    """ implemented in the class"""    
    
    def populate_graph(self, num_users, avg_friendships):
        """
        This was done in the class
        
        Takes a number of users and an average number of friendships
        as arguments

        Creates that number of users and a randomly distributed friendships
        between those users.

        The number of users must be greater than the average number of friendships.
        """
       
    def get_all_social_paths(self, user_id):
        """
        Takes a user's user_id as an argument

        Returns a dictionary containing every user in that user's
        extended network with the shortest friendship path between them.

        The key is the friend's ID and the value is the path.
        """
      

if __name__ == '__main__':
    sg = SocialGraph()
    sg.populate_graph(10, 2)
    print(sg.friendships)
    connections = sg.get_all_social_paths(1)
    print(connections)
